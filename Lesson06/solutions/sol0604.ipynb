# %%
n = len(thedata["Days"]) # this is just 7, so you could have used it (less flexibly) below
for i in range(n):
    day = thedata["Days"][i]
    temp = thedata["Temperatures"][i]
    print(day, ',', temp)
