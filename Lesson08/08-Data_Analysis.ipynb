# %% [markdown]
# Run all cells marked `In [ ]` using the [$\blacktriangleright$ Run] button above and **think about the result you see**.
# Be sure to do all exercises (in blank cells) and run all completed code cells.
#
# If anything goes wrong, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart). Or run text cells to get the formatted text back from markdown.

# %% [markdown]
# ---

# %% [markdown]
# # Basics of Plotting Graphs

# %% [markdown]
# ## Matplotlib
#
# Matplotlib, and particularly its plotting capabilities in `pyplot`, are used to create publication quality figures of functions and data. The functionality is vast, and you will need to refer to the documentation frequently until you are familiar with what you need from it and the details of how it is used:
# https://matplotlib.org/stable/tutorials/introductory/usage.html.
# Most of the functionality we will be using are contained in the `pyplot` functionality of Matplotlib, which is normally accessed using:
#
# ```python
# import matplotlib.pyplot as plt
# ```
# The various plotting tools and ways of specifying figure attributes are then accessed using the syntax:
# ```python
# plt.ATTRIBUTE(ARGUMENTS)
#
# ```
# Where `ATTRIBUTE` is replaced by the name of the function or other attribute you wish to access.
#
# ## Simple Plotting
#
# In its simplest terms the `plot()` function in `pyplot` takes a list of $x$ values and plots each one on the $x-$axis against a  corresponding $y-$value from a list of $y$ values of the same length.
#
# This is demonstrated for the squares of $x=[1,2,3,4]$ below:

# %%
import numpy as np
import matplotlib.pyplot as plt


xvals = np.array([1,2,3,4])
yvals = xvals**2

plt.plot(xvals, yvals)
plt.xlabel('x')
plt.ylabel('$x^2$')
# Out:
# Text(0, 0.5, '$x^2$')

# %% [markdown]
# Many online examples and AI generated code will use this simple *implicit* method for plotting, so you should be aware of it. A nice introductory guide can be found here:
# https://matplotlib.org/stable/tutorials/pyplot.html
#
# These notes will use a more flexible (object oriented) method that allows much more fine control over figures:
# https://matplotlib.org/stable/users/explain/quick_start.html
#
# ### Creating a set of Figure *axes*
#
# The [`plt.subplots`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html#matplotlib.pyplot.subplots) function returns two things: a **fig**ure _canvas_ to construct a figure on, and a set of _**ax**es_ to draw specific plots on.
# * The `fig` object has `.ATTRIBUTES` for changing things such as the figure title, axis labels and decorations
# * The `ax` object has `.ATTRIBUTES` such as functions for specific plot types etc.

# %%
fig, ax = plt.subplots()

# %% [markdown]
# Once you have some axes (on a figure) you can start drawing things directly on them.
#
# ### Example: Sine Wave
#
# To plot a sine wave between $0$ and $\pi$:

# %%
pi=np.pi

# create a single set of axes on a figure
fig, ax = plt.subplots()

xvals = np.linspace(-pi,pi,100)
sinx = np.sin(xvals)

ax.plot(xvals, sinx)

# %% [markdown]
# ## Multiple axes on the same plot
#
# The possible arguments to `plt.subplots()` are given in the documentation here: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html#matplotlib.pyplot.subplots
#
# ```python
# matplotlib.pyplot.subplots(nrows=1, ncols=1, *, sharex=False,
#                   sharey=False, squeeze=True, subplot_kw=None,
#                   gridspec_kw=None, **fig_kw)
# ```
#
# Of particular interest are the number of rows `nrows` and columns `ncols` of axes on the figure.
# If you don't specify these, there will only be a single set of axes as above, but if you give two values as arguments they stand for the number of rows and number of columns.
# The `ax` object will then be a `[list]` of axes or a set of axes, depending on how you unpack the returned values:

# %%
fig, axs = plt.subplots(2)

axs[0].plot(xvals, np.sin(xvals))
axs[1].plot(xvals, np.cos(xvals))

# %% [markdown]
# For a square $2\times 2$ grid:

# %%
fig, axs = plt.subplots(2, 2)

[[ax1, ax2], [ax3, ax4]] = axs

ax1.plot(xvals, np.sin(xvals)) # x vs sin(x)
ax2.plot(np.sin(xvals), xvals) # flipped axes
ax3.plot(xvals, np.cos(xvals)) # x vs cos(x)
ax4.plot(np.sin(xvals), np.cos(xvals)) # parametric plot of sin(x) vs cos(x)

# %% [markdown]
# ## Changing the Plotting Attributes
#
# ### Plotting Styles
#
# We can change the plotting style (and many other features) using extra arguments to the `subplots` and `plot` functions.
# The plot attributes can be given as keyword arguments after the x-values and y-values.
# The arguments are given as strings and consist of either a symbol to specify a marker or line type or the colour
# (spelled using the American spelling `color`, without a "u"):

# %%
import numpy as np
import matplotlib.pyplot as plt

xvals = np.arange(11)
yvals = xvals**2

# set some x and y dimensions (in inch !!!)
dims = (8,8)
fig, ax = plt.subplots(figsize=dims) # specify the size of the figure

ax.plot(xvals, yvals, linestyle='--', marker='o', color='red')

plt.show()

# %% [markdown]
# Use `help(ax.plot)` (in a new NoteBook) to see what else is available and experiment with line styles and points etc., as well as online resources.
#
# ### Multiple Plots on the same axis
#
# The following example shows that we can plot more than one function on the same graph.
# A different colour is automatically used for each function.

# %%
import numpy as np
import matplotlib.pyplot as plt
pi = np.pi

xs = np.linspace(0, 2*pi, 50)
ys = np.sin(xs)
zs = np.cos(xs)

fig, ax = plt.subplots()

ax.plot(xs, ys)
ax.plot(xs, zs)

# %% [markdown]
# ### Labels and Legends
#
# The plot can be improved by adding labels for the horizontal and vertical axes and  a legend.

# %%
ax.set_xlabel("Angle t (radians)", size=12)
ax.set_ylabel("f (t)", size=12)

labels=["sin(t)", "cos(t)"]
ax.legend(labels)

fig # shows the figure again

# %% [markdown]
# ## Saving Figures to a File on Your Hard Drive
#
# `fig.savefig('FILENAME.extension')` saves the figure to a file named `FILENAME` with the image format given by the `.extension`: e.g.: `.png` `.jpg` `.pdf` etc.

# %%
# run the code above (or paste it here) before running this cell

plt.savefig('sinusoids.png')

# %% [markdown]
# * Notice a file has appeared in your working folder for this lesson that could be used in a report or other document.
#
# A useful thing to do is to define a function that does all the steps of creating a figure template, so you can apply it to lots of different datasets.
#
# The example below has quite a lot going on, so take your time to study it and try changing some of the figure properties for yourself.

# %%
import numpy as np, matplotlib.pyplot as plt

def plotter(xdata, ydata):
    fig,ax = plt.subplots(1,2, figsize=(10,4))
    ax[0].plot(xdata,ydata, linewidth=0.2, color='red', marker='*', markerfacecolor='green')
    ax[1].hist(ydata, orientation='horizontal', edgecolor='black')
    ax[0].set_ylabel('Data Values', size=12)
    ax[0].set_xlabel('Data Index', size=12)
    ax[1].set_xlabel('Data Counts', size=12)
    ax[0].set_xlim(0,300)
    for i in [0,1]:
        ax[i].grid() 
        ax[i].set_ylim(0,80)
    ax[0].text(-50,0,'(a)', size=15)
    ax[1].text(-10,0,'(b)', size=15)
    
    return fig

##########
x = np.arange(1,301)
y = np.random.normal(42,12,300)
fig = plotter(x,y)
##########

fig.savefig('fancyfig.pdf')

# %% [markdown]
# The plots using Pandas in the next section can be manipulated in similar ways using matplotlib.

# %% [markdown]
# # Data analysis using Pandas

# %% [markdown]
# ## Returning to dictionaries
#
# Dictionary entries can also be numerical arrays (as well as any other object)

# %%
import numpy as np

thedata = dict() #another way of making an empty dictionary

thedata["Days"] = list(range(1,8))
thedata["Temperatures"] = np.array([23.3, 16.9, 21.8, 26.9, 23.5, 21.7, 19.8])

thedata
# Out:
# {'Days': [1, 2, 3, 4, 5, 6, 7],
#  'Temperatures': array([23.3, 16.9, 21.8, 26.9, 23.5, 21.7, 19.8])}

# %% [markdown]
# Which can also be manipulated:

# %%
thedata["Temperatures"] = thedata["Temperatures"]-10

thedata["Temperatures"]
# Out:
# array([13.3,  6.9, 11.8, 16.9, 13.5, 11.7,  9.8])

# %% [markdown]
# ## Data Frames and Pandas
#
# Pandas is a very powerful data analysis library that extends on the functionality of numpy and matplotlib.
# It can be used to load, analyse plot and save data.
#
# ### See the comprehensive cheatsheet on moodle for full information about Pandas
#
#
# The basic data types used by pandas are the dataframe and the series. Here we'll look at dataframes, which are 2D arrays with labels and related to a spreadsheet.

# %%
import pandas as pd

# make a dataframe called df out of our previous dictionary:
df = pd.DataFrame(thedata)
print(df)
# Out:
#    Days  Temperatures
# 0     1          13.3
# 1     2           6.9
# 2     3          11.8
# 3     4          16.9
# 4     5          13.5
# 5     6          11.7
# 6     7           9.8

# %% [markdown]
# In Jupyter-Notebooks dataframes will display with nice formatting by putting just their name at the end of a code cell:

# %%
df
# Out:
#    Days  Temperatures
# 0     1          13.3
# 1     2           6.9
# 2     3          11.8
# 3     4          16.9
# 4     5          13.5
# 5     6          11.7
# 6     7           9.8

# %% [markdown]
# Columns can be accessed in the same way as dictionaries:

# %%
df["Temperatures"]
# Out:
# 0    13.3
# 1     6.9
# 2    11.8
# 3    16.9
# 4    13.5
# 5    11.7
# 6     9.8
# Name: Temperatures, dtype: float64

# %% [markdown]
# And they can be manipulated like Numpy arrays:

# %%
average = df["Temperatures"].mean()
print(average)

deviation = df["Temperatures"]-average
print(deviation)
# Out:
# 11.985714285714284
# 0    1.314286
# 1   -5.085714
# 2   -0.185714
# 3    4.914286
# 4    1.514286
# 5   -0.285714
# 6   -2.185714
# Name: Temperatures, dtype: float64

# %% [markdown]
# As well as writing new columns:

# %%
df["Deviations"] = deviation

df
# Out:
#    Days  Temperatures  Deviations
# 0     1          13.3    1.314286
# 1     2           6.9   -5.085714
# 2     3          11.8   -0.185714
# 3     4          16.9    4.914286
# 4     5          13.5    1.514286
# 5     6          11.7   -0.285714
# 6     7           9.8   -2.185714

# %% [markdown]
# This can then be saved as a CSV using `df.to_csv("<FILENAME>.csv")` or even an Excel spreadsheet:
#
# * Note: the `index=False` argument makes sure the left-hand index column (`[0,1,2,3,4,5,6]`) does **not** get written to the spreadsheet.
# * The `sheet_name` argument allows you to name the sheet tab in Excel.

# %%
df.to_excel("devdata.xlsx", index=False, sheet_name="Temperature Deviations")

# %%
df.to_csv("devdata.csv", index=False)

# %% [markdown]
# * Now download and open the `devdata.xlsx` file that was just created!
#
# Lists and arrays can also be used to make Data-Frames:

# %%
import numpy as np
import pandas as pd

temps = np.array([23.3, 16.9, 21.8, 26.9, 23.5, 21.7, 19.8])
average = temps.mean()
devs = temps-average # deviation of each point from the mean
stdev = temps.std() # standard deviation of the dataset
zscore = devs/stdev # Z-score is the number of standard deviations each reading is from the mean
data = [temps, devs, zscore]

mynewdataframe = pd.DataFrame(data)
mynewdataframe
# Out:
#            0          1          2          3          4          5          6
# 0  23.300000  16.900000  21.800000  26.900000  23.500000  21.700000  19.800000
# 1   1.314286  -5.085714  -0.185714   4.914286   1.514286  -0.285714  -2.185714
# 2   0.452977  -1.752823  -0.064008   1.693739   0.521908  -0.098473  -0.753320

# %%
# rotate the dataframe:
newdata = mynewdataframe.transpose()
newdata
# Out:
#       0         1         2
# 0  23.3  1.314286  0.452977
# 1  16.9 -5.085714 -1.752823
# 2  21.8 -0.185714 -0.064008
# 3  26.9  4.914286  1.693739
# 4  23.5  1.514286  0.521908
# 5  21.7 -0.285714 -0.098473
# 6  19.8 -2.185714 -0.753320

# %% [markdown]
# * Data can be accessed and manipulated in similar ways to 2D arrays, but also accessed by the column name, new columns can be inserted etc.
#
# A dataframe also has an *object* variable `.columns` inside which describes the column headings.
# * In the above example `newdata.columns = [0, 1, 2]` by default.

# %% [markdown]
# #### Renaming the columns

# %%
newdata.columns = "Temp", "Deviation", "Z-value"

newdata
# Out:
#    Temp  Deviation   Z-value
# 0  23.3   1.314286  0.452977
# 1  16.9  -5.085714 -1.752823
# 2  21.8  -0.185714 -0.064008
# 3  26.9   4.914286  1.693739
# 4  23.5   1.514286  0.521908
# 5  21.7  -0.285714 -0.098473
# 6  19.8  -2.185714 -0.753320

# %% [markdown]
# A dataframe also has a `.index` property naming the rows, which can be changed:

# %%
newdata.index = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]

newdata
# Out:
#      Temp  Deviation   Z-value
# Mon  23.3   1.314286  0.452977
# Tue  16.9  -5.085714 -1.752823
# Wed  21.8  -0.185714 -0.064008
# Thu  26.9   4.914286  1.693739
# Fri  23.5   1.514286  0.521908
# Sat  21.7  -0.285714 -0.098473
# Sun  19.8  -2.185714 -0.753320

# %% [markdown]
# See the very comprehensive sheet on moodle (also ones such as [this one](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)) to find out more details.
#
# ### Importing spreadsheet data
#
# It is possible to import data into a data-frame from plain text files, CSV files or even excel spreadsheets.

# %%
import pandas as pd

data = pd.read_excel("Files/Case Study Data.xlsx", sheet_name="Data")

data
# Out:
# /home/macha/anaconda3/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse
# 33     6500.000000         1.098500e+06                     169.000000
# 34     7185.000000         7.008530e+05                      97.600000
# 35    18000.000000         2.052000e+06                     114.000000
# 36    33000.000000         4.929499e+06                     160.000000
# 37    12536.000000         2.295816e+06                     183.000000
# 38    10366.000000         2.467108e+06                     238.000000
# 39    14239.000000         1.980000e+06                     139.000000
# 40    75809.000000         4.472731e+06                      59.000000
# 41    18399.000000         2.907042e+06                     158.000000
# 42    53372.000000         8.966496e+06                     168.000000
# 43    52112.714286         1.203804e+07                     231.000000
# 44    78500.000000         2.457050e+07                     313.000000
# 45    60000.000000         2.028000e+07                     338.000000
# 46     4500.000000         1.831500e+05                      40.700000
# 47    19975.000000         2.692630e+06                     134.800000
# 48     3055.000000         1.235136e+05                      40.430000
#
#     Electricity.Intensity.kWh.sqm.y  Gas.Intensity.kWh.sqm.y  Water.L.sqm  \
# 0                               NaN                      NaN          NaN
# 1                         47.000000               105.000000    69.000000
# 2                        307.000000                67.000000          NaN
# 3                         53.700000                      NaN   330.000000
# 4                        306.000000               232.000000          NaN
# 5                               NaN                      NaN   602.000000
# 6                               NaN                      NaN          NaN
# 7                         83.000000                      NaN   130.000000
# 8                         38.750078                 4.305564   425.000000
# 9                         60.277898                 7.534737          NaN
# 10                       189.000000               281.000000   459.000000
# 11                              NaN                      NaN    89.517889
# 12                        64.583463                36.597295          NaN
# 13                       181.800000                      NaN   559.625000
# 14                       123.656737                      NaN   208.000000
# 15                       186.000000                14.000000          NaN
# 16                       222.000000                      NaN    75.000000
# 17                       168.697168                86.302832          NaN
# 18                       149.000000                      NaN   638.000000
# 19                       152.000000                32.000000   325.000000
# 20                        86.800000                      NaN   221.000000
# 21                       228.000000                      NaN          NaN
# 22                        35.000000                12.000000   121.000000
# 23                        22.900000                62.800000          NaN
# 24                        61.100000                36.600000   681.000000
# 25                        41.900000                67.300000          NaN
# 26                              NaN                      NaN          NaN
# 27                        96.700000                71.500000   681.000000
# 28                        74.000000                      NaN          NaN
# 29                        36.300000                12.900000   152.000000
# 30                        74.300000                      NaN   453.000000
# 31                              NaN                      NaN   168.000000
# 32                       109.791886                13.993084          NaN
# 33                       169.000000                      NaN          NaN
# 34                        66.400000                13.600000   725.000000
# 35                        99.484000                13.700000   117.000000
# 36                        96.200000                64.100000          NaN
# 37                        77.200000               106.000000   592.000000
# 38                       128.000000               109.500000   463.000000
# 39                              NaN                      NaN          NaN
# 40                              NaN                      NaN   304.000000
# 41                              NaN                      NaN          NaN
# 42                       168.000000                      NaN   580.000000
# 43                       156.000000                73.900000   714.000000
# 44                              NaN                      NaN   260.000000
# 45                              NaN                      NaN   462.000000
# 46                              NaN                      NaN    98.000000
# 47                              NaN                      NaN          NaN
# 48                              NaN                      NaN          NaN
#
#     PV.Intensity.kWh.sqm  Solar.Thermal.kWh.sqm  Steam.kWh.sqm  \
# 0                    NaN                    NaN            NaN
# 1               4.500000                    NaN            NaN
# 2                    NaN                    NaN            NaN
# 3                    NaN                    NaN            NaN
# 4                    NaN                    NaN            NaN
# 5                    NaN                    NaN            NaN
# 6                    NaN                    NaN            NaN
# 7              15.400000                    NaN            NaN
# 8               5.500000                    NaN            NaN
# 9               6.458346                    NaN            NaN
# 10              1.200000                    NaN            NaN
# 11                   NaN                    NaN            NaN
# 12                   NaN                    NaN            NaN
# 13                   NaN                    NaN            NaN
# 14                   NaN                    NaN      65.014019
# 15                   NaN                    NaN            NaN
# 16              5.700000                    NaN            NaN
# 17              1.100000                    0.2            NaN
# 18              0.800000                    NaN     136.000000
# 19                   NaN                    NaN            NaN
# 20                   NaN                    NaN            NaN
# 21                   NaN                    NaN            NaN
# 22                   NaN                    NaN            NaN
# 23                   NaN                    NaN            NaN
# 24                   NaN                    NaN            NaN
# 25              9.200000                    NaN            NaN
# 26                   NaN                    NaN            NaN
# 27                   NaN                    NaN            NaN
# 28                   NaN                    NaN            NaN
# 29                   NaN                    3.1            NaN
# 30                   NaN                    NaN            NaN
# 31                   NaN                    NaN            NaN
# 32                   NaN                    NaN            NaN
# 33                   NaN                    NaN            NaN
# 34                   NaN                    NaN            NaN
# 35                   NaN                    NaN            NaN
# 36                   NaN                    NaN            NaN
# 37                   NaN                    NaN            NaN
# 38                   NaN                    NaN            NaN
# 39             18.700000                    NaN            NaN
# 40                   NaN                    NaN            NaN
# 41                   NaN                    NaN            NaN
# 42                   NaN                    NaN            NaN
# 43              1.300000                    NaN            NaN
# 44                   NaN                    NaN            NaN
# 45                   NaN                    NaN            NaN
# 46                   NaN                    NaN            NaN
# 47                   NaN                    NaN            NaN
# 48                   NaN                    NaN            NaN
#
#     District.Heating.Intensity.kWh.sqm  District.Cooling.Intensity.kWh.sqm  \
# 0                                  NaN                                 NaN
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
# 3                                  NaN                                 NaN
# 4                                  NaN                                 NaN
# 5                                  NaN                                 NaN
# 6                                  NaN                                 NaN
# 7                                  NaN                                 NaN
# 8                                  NaN                                 NaN
# 9                                  NaN                                 NaN
# 10                                 NaN                                 NaN
# 11                                 NaN                                 NaN
# 12                                 NaN                                 NaN
# 13                                 NaN                                 NaN
# 14                                 NaN                                 NaN
# 15                                 NaN                                 NaN
# 16                                 NaN                                 NaN
# 17                                 NaN                                 NaN
# 18                                 NaN                                 NaN
# 19                                 NaN                                 NaN
# 20                                89.2                                39.4
# 21                                 NaN                                 NaN
# 22                                 NaN                                 NaN
# 23                                 NaN                                 NaN
# 24                                 NaN                                 NaN
# 25                                 NaN                                 NaN
# 26                                 NaN                                 NaN
# 27                                 NaN                                 NaN
# 28                                43.0                                18.0
# 29                                 NaN                                 NaN
# 30                                 NaN                                 NaN
# 31                                 NaN                                 NaN
# 32                                 NaN                                 NaN
# 33                                 NaN                                 NaN
# 34                                 NaN                                 NaN
# 35                                 NaN                                 NaN
# 36                                 NaN                                 NaN
# 37                                 NaN                                 NaN
# 38                                 NaN                                 NaN
# 39                                 NaN                                 NaN
# 40                                 NaN                                 NaN
# 41                                 NaN                                 NaN
# 42                                 NaN                                 NaN
# 43                                 NaN                                 NaN
# 44                                 NaN                                 NaN
# 45                                 NaN                                 NaN
# 46                                 NaN                                 NaN
# 47                                 NaN                                 NaN
# 48                                 NaN                                 NaN
#
#     CHP.generated.Elec.kWh.sqm  CHP.generated.Heat.kWh.sqm  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# 5                          NaN                         NaN
# 6                          NaN                         NaN
# 7                          NaN                         NaN
# 8                          NaN                         NaN
# 9                          NaN                         NaN
# 10                         NaN                         NaN
# 11                         NaN                         NaN
# 12                         NaN                         NaN
# 13                         NaN                         NaN
# 14                         NaN                         NaN
# 15                         NaN                         NaN
# 16                         NaN                         NaN
# 17                         NaN                         NaN
# 18                         NaN                         NaN
# 19                         NaN                         NaN
# 20                         NaN                         NaN
# 21                         NaN                         NaN
# 22                         NaN                         NaN
# 23                         NaN                         NaN
# 24                         NaN                         NaN
# 25                        71.3                       148.0
# 26                         NaN                         NaN
# 27                         NaN                         NaN
# 28                         NaN                         NaN
# 29                         NaN                         NaN
# 30                         NaN                         NaN
# 31                         NaN                         NaN
# 32                         NaN                         NaN
# 33                         NaN                         NaN
# 34                         NaN                         NaN
# 35                         NaN                         NaN
# 36                         NaN                         NaN
# 37                         NaN                         NaN
# 38                         NaN                         NaN
# 39                         NaN                         NaN
# 40                         NaN                         NaN
# 41                         NaN                         NaN
# 42                         NaN                         NaN
# 43                         NaN                         NaN
# 44                         NaN                         NaN
# 45                         NaN                         NaN
# 46                         NaN                         NaN
# 47                         NaN                         NaN
# 48                         NaN                         NaN
#
#     Biomass.Boiler.kWh.sqm.y
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23                       NaN
# 24                       NaN
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28                       NaN
# 29                       NaN
# 30                       NaN
# 31                       NaN
# 32                 38.750078
# 33                       NaN
# 34                       NaN
# 35                       NaN
# 36                       NaN
# 37                       NaN
# 38                       NaN
# 39                       NaN
# 40                       NaN
# 41                       NaN
# 42                       NaN
# 43                       NaN
# 44                       NaN
# 45                       NaN
# 46                       NaN
# 47                       NaN
# 48                       NaN

# %% [markdown]
# Individual columns can be extracted using the following syntax:

# %%
projects = data["Project"]

print(projects)
# Out:
# 0                                Manitoba Hydro Place
# 1                            Child Development Centre
# 2                FIPKE Centre for Innovative Research
# 3                                       Transoceanica
# 4                                    The Cooper Union
# 5                               Biodesign Institute B
# 6     DELL Children's Medical Center of Central Texas
# 7                                          Kroon Hall
# 8                     Newark Center at Ohlone College
# 9             Tahoe Center for Environmental Sciences
# 10              Center for Health and Healing, Oregon
# 11                   NREL Research Support Facility 1
# 12                                        Twelve West
# 13                               2000 Tower Oaks Blvd
# 14                                      Regent's Hall
# 15                                 Great River Energy
# 16                Lewis & Clark State Office building
# 17                            Johnson Controls Campus
# 18                                     Genzyme Center
# 19                                               CSOB
# 20                                         Lintulahti
# 21                                           EMGP 270
# 22                               Paul Wunderlich-Haus
# 23                       Federal Environmental Agency
# 24                           Heinrich Boll Foundation
# 25                                 Solon Corporate HQ
# 26                                    Thyssenkrupp Q1
# 27                                                SAP
# 28                                       Hagaporten 3
# 29                             Eawag Forum Chriesbach
# 30                              Daniel Swarovski Corp
# Center for Health and Healing, Oregon                  145.400000
# NREL Research Support Facility 1                        91.400000
# Twelve West                                            138.000000
# 2000 Tower Oaks Blvd                                    63.600000
# Regent's Hall                                           63.000000
# Great River Energy                                      65.000000
# Lewis & Clark State Office building                     18.100000
# Johnson Controls Campus                                 73.000000
# Genzyme Center                                         140.000000
# CSOB                                                   107.000000
# Lintulahti                                              29.500000
# EMGP 270                                                24.900000
# Paul Wunderlich-Haus                                    32.265000
# Federal Environmental Agency                            91.800000
# Heinrich Boll Foundation                                16.875000
# Solon Corporate HQ                                      63.450000
# Thyssenkrupp Q1                                        116.000000
# SAP                                                     18.000000
# Hagaporten 3                                           130.000000
# Eawag Forum Chriesbach                                  32.745000
# Daniel Swarovski Corp                                   57.000000
# TNT Express HQ                                                NaN
# 3 Assembly Square                                       19.500000
# Suttie Centre                                           22.356000
# 2 Victoria Avenue                                             NaN
# Workplace6                                              52.080000
# One Shelley Street                                            NaN
# Council House 2                                         71.740200
# The Gague                                                     NaN
# Vanke Center                                                  NaN
# Suzlon One Earth                                              NaN
# Keio University 4th Building Hiyoshi Campus                   NaN
# Epson Innovation Center                                       NaN
# Honda Wako                                                    NaN
# Nissan Global HQ                                              NaN
# Kansai Electric Power HQ                                      NaN
# Zero Energy Building                                     8.800000
# School of Art, Design, Media at NTU                     28.800000
# Magic School of Green Technology                         6.000000

# %%
import pandas as pd

data = pd.read_excel("Files/Case Study Data.xlsx", sheet_name="Data")

cost = data["Cost.Million.USD"]
area = data["Total.Area.sqm"]
costpermetre2 = cost/area

# create a new column
data["Cost.Per.sqm"] = costpermetre2


selected_columns = ["Project", "Total.Area.sqm", "Cost.Million.USD", "Cost.Per.sqm"]

# create a new DataFrame with the selected columns as the data and set the project name column as the index
newdata = data[selected_columns].set_index("Project")

newdata
# Out:
# /home/macha/anaconda3/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
#                                                  Total.Area.sqm  \
# Project
# Manitoba Hydro Place                               65000.000000
# Child Development Centre                           11612.140575
# FIPKE Centre for Innovative Research                6323.794118
# Transoceanica                                      13959.068901
# The Cooper Union                                   16255.124535
# Biodesign Institute B                              27184.466019
# DELL Children's Medical Center of Central Texas    43948.234956
# Kroon Hall                                          6205.254065
# Newark Center at Ohlone College                    12806.321244
# Tahoe Center for Environmental Sciences             4374.310680
# Center for Health and Healing, Oregon              38143.178709
# NREL Research Support Facility 1                   33457.000000
# Twelve West                                        39747.000000
# 2000 Tower Oaks Blvd                               18619.361936
# Regent's Hall                                      17859.989362
# Great River Energy                                 15434.070000
# Lewis & Clark State Office building                11324.251203
# Johnson Controls Campus                            28745.989412
# Genzyme Center                                     32021.614035
# CSOB                                               82365.580435
# Lintulahti                                         12885.708920
# EMGP 270                                            9983.377193
# Paul Wunderlich-Haus                               22000.000000
# Federal Environmental Agency                       41000.000000
# Heinrich Boll Foundation                            6964.509202
# Solon Corporate HQ                                 33451.000000
# Thyssenkrupp Q1                                    29000.000000
# SAP                                                 6000.000000
# Hagaporten 3                                       30000.000000
# Twelve West                                          0.003472
# 2000 Tower Oaks Blvd                                 0.003416
# Regent's Hall                                        0.003527
# Great River Energy                                   0.004211
# Lewis & Clark State Office building                  0.001598
# Johnson Controls Campus                              0.002539
# Genzyme Center                                       0.004372
# CSOB                                                 0.001299
# Lintulahti                                           0.002289
# EMGP 270                                             0.002494
# Paul Wunderlich-Haus                                 0.001467
# Federal Environmental Agency                         0.002239
# Heinrich Boll Foundation                             0.002423
# Solon Corporate HQ                                   0.001897
# Thyssenkrupp Q1                                      0.004000
# SAP                                                  0.003000
# Hagaporten 3                                         0.004333
# Eawag Forum Chriesbach                               0.003837
# Daniel Swarovski Corp                                0.004514
# TNT Express HQ                                            NaN
# 3 Assembly Square                                    0.003193
# Suttie Centre                                        0.003439
# 2 Victoria Avenue                                         NaN
# Workplace6                                           0.002893
# One Shelley Street                                        NaN
# Council House 2                                      0.005723
# The Gague                                                 NaN
# Vanke Center                                              NaN
# Suzlon One Earth                                          NaN
# Keio University 4th Building Hiyoshi Campus               NaN
# Epson Innovation Center                                   NaN
# Honda Wako                                                NaN
# Nissan Global HQ                                          NaN
# Kansai Electric Power HQ                                  NaN
# Zero Energy Building                                 0.001956
# School of Art, Design, Media at NTU                  0.001442
# Magic School of Green Technology                     0.001964

# %% [markdown]
# Pandas is very good at plotting the data.

# %%
ax = newdata["Total.Area.sqm"].plot(kind="bar", figsize=(15,5)) # returns a set of figure axes

# %% [markdown]
# Different plot styles are available

# %%
ax1 = newdata["Total.Area.sqm"].plot.hist(edgecolor="black")
ax2 = newdata.plot.scatter(x="Total.Area.sqm", y="Cost.Million.USD")

# %% [markdown]
# Plots can be saved or manipulated using this method:

# %%
ax2.figure.savefig("scatterplot.png") # how to access the figure canvas and save it

# %% [markdown]
# And plots can appear on the same axes or in subplots.

# %%
sortdata = newdata.sort_values(by="Total.Area.sqm")

ax3 = sortdata.plot.bar(subplots=True, figsize=(15,9))

# %% [markdown]
# ### Filtering data:
#
# Data can also be filtered in the following way:

# %%
costmilUSD = data2["Cost.Million.USD"] #select the column 

condition = costmilUSD>100 #filter selected values

data3 = data2[condition]

data3
# Out:
#                                                  Total.Area.sqm  \
# Project
# Manitoba Hydro Place                               65000.000000
# The Cooper Union                                   16255.124535
# DELL Children's Medical Center of Central Texas    43948.234956
# Center for Health and Healing, Oregon              38143.178709
# Twelve West                                        39747.000000
# Genzyme Center                                     32021.614035
# CSOB                                               82365.580435
# Thyssenkrupp Q1                                    29000.000000
# Hagaporten 3                                       30000.000000
#
#                                                  Cost.Million.USD
# Project
# Manitoba Hydro Place                                       269.66
# The Cooper Union                                           112.00
# DELL Children's Medical Center of Central Texas            137.00
# Center for Health and Healing, Oregon                      145.40
# Twelve West                                                138.00
# Genzyme Center                                             140.00
# CSOB                                                       107.00
# Thyssenkrupp Q1                                            116.00
# Hagaporten 3                                               130.00

# %% [markdown]
# * Try breaking this down and printing each line to see what's going on in each step.
#
# This can then be combined into a single line, which is more compact but harder to read.
# ```python
# data3 = data2[data2["Cost.Million.USD"]>100]
# ```
